# %%
# !rm diabetes.sqlite
# !rm diabetes.sqlite-journal

PWD = !pwd
PWD = PWD[0]
PWD
# Out:
# rm: impossibile rimuovere 'diabetes.sqlite-journal': File o directory non esistente
# '/home/lore/Documents/GitHub/DataMining/ex2'

# %%
#The Code field is deciphered as follows:
CODES = """
33 = Regular insulin dose
34 = NPH insulin dose
35 = UltraLente insulin dose
48 = Unspecified blood glucose measurement
56 = Unknown
57 = Unspecified blood glucose measurement
58 = Pre-breakfast blood glucose measurement
59 = Post-breakfast blood glucose measurement
60 = Pre-lunch blood glucose measurement
61 = Post-lunch blood glucose measurement
62 = Pre-supper blood glucose measurement
63 = Post-supper blood glucose measurement
64 = Pre-snack blood glucose measurement
65 = Hypoglycemic symptoms
66 = Typical meal ingestion
67 = More-than-usual meal ingestion
68 = Less-than-usual meal ingestion
69 = Typical exercise activity
70 = More-than-usual exercise activity
71 = Less-than-usual exercise activity
72 = Unspecified special event
"""

PATIENT_PATH = "dataset/data-{}"
PATIENTS = [1,70]

# %%
from pony.orm import *
from datetime import datetime, timedelta
import pandas as pd
from io import StringIO
import numpy as np

DB = Database()
DB.bind('sqlite', f"{PWD}/diabetes.sqlite", create_db=True)

# %%
def has_subseq(seq, subseq):
    i,j = 0,0
    while i < len(seq) and j < len(subseq):
        if seq[i] == subseq[j]:
            j += 1
        i += 1
    return j == len(subseq)

# %%
class Label(DB.Entity):
    code = PrimaryKey(int)
    name = Required(str)
    labels = Set("EventLabel")

    @staticmethod
    def load_codes():
        df_code = pd.read_csv(
            StringIO(CODES), sep="=", header=None, names=["code", "label"]
        )
        for row in df_code.iterrows():
            Label(code=row[1].to_dict()["code"], name=row[1].to_dict()["label"])
        DB.commit()

    def to_dataframe(self):
        return pd.DataFrame(
            [e.event.to_dict() | e.to_dict() | self.to_dict() for e in self.labels]
        )


class EventLabel(DB.Entity):
    event = Required("Event")
    label = Required(Label)
    value = Required(str)
    PrimaryKey(event, label)


class Event(DB.Entity):
    patient_id = Required(int)
    vt = Required(datetime)
    labels = Set(EventLabel)
    PrimaryKey(patient_id, vt)

    @staticmethod
    def event_slices(patient, days=1, stride=1):
        # exercise: a function that produce the window-stride sequences of a given patient
        slices = []
        start_day = min(e.vt for e in Event if e.patient_id == patient)
        end_day = max(e.vt for e in Event if e.patient_id == patient)

        while start_day + timedelta(days=days) <= end_day:
            events = list(
                select(
                    e.labels.label.code
                    for e in Event
                    if e.patient_id == patient
                    and e.vt >= start_day
                    and e.vt < start_day + timedelta(days=days)
                )
            )
            if len(events) > 0:
                slices.append(events)
            start_day = start_day + timedelta(days=stride)

        return slices

    @staticmethod
    def count_seq(seq, patient, days=1, stride_days=1):
        slices = Event.event_slices(patient, days, stride_days)
        count = 0
        for s in slices:
            if has_subseq(s, seq):
                count += 1
        return count


    @staticmethod
    def load_partecipant(id):
        skipped = 0
        df = pd.read_csv(PATIENT_PATH.format(str(id).zfill(2)), sep="\t", header=None)
        for r in df.iterrows():
            d = r[1].to_dict()
            try:
                vt = datetime.strptime(d[0] + " " + d[1], "%m-%d-%Y %H:%M")
                event = Event.get(patient_id=id, vt=vt)
                if event is None:
                    event = Event(patient_id=id, vt=vt)
                new_label = EventLabel(event=event, label=Label[d[2]], value=str(d[3]))
                event.labels.add(new_label)
            except Exception as e:
                skipped = skipped + 1
                print(e)
                print(f"partecipant {id} cannot insert {d}")
        DB.commit()
        print(f"Skipped lines subject {id}: {skipped}")

    @staticmethod
    def load_partecipants():
        i = PATIENTS[0]
        while i <= PATIENTS[1]:
            Event.load_partecipant(i)
            i = i + 1

    def full_dict(self):
        return [
            {
                "vt": self.vt,
                "patient": self.patient_id,
                "label": label.label.name,
                "code": label.label.code,
            }
            for label in self.labels
        ]

    @staticmethod
    def full_dataset():
        r = []
        for e in list(Event.select()):
            r += e.full_dict()
        return pd.DataFrame(r)

# %%
DB.generate_mapping(create_tables=True)

# %%
Label.load_codes()

# %%
Event.load_partecipants()
# Out:
# Skipped lines subject 1: 0
# Skipped lines subject 2: 0
# Cannot create EventLabel: instance with primary key Event[3,datetime.datetime(1990, 7, 30, 5, 28)], Label[33] already exists
# partecipant 3 cannot insert {0: '07-30-1990', 1: '05:28', 2: 33, 3: 3}
# Cannot create EventLabel: instance with primary key Event[3,datetime.datetime(1990, 8, 1, 16, 28)], Label[65] already exists
# partecipant 3 cannot insert {0: '08-01-1990', 1: '16:28', 2: 65, 3: 0}
# Skipped lines subject 3: 2
# Skipped lines subject 4: 0
# Skipped lines subject 5: 0
# Skipped lines subject 6: 0
# Skipped lines subject 7: 0
# Cannot create EventLabel: instance with primary key Event[8,datetime.datetime(1990, 8, 14, 10, 8)], Label[65] already exists
# partecipant 8 cannot insert {0: '08-14-1990', 1: '10:08', 2: 65, 3: 0}
# Cannot create EventLabel: instance with primary key Event[8,datetime.datetime(1990, 8, 15, 7, 26)], Label[33] already exists
# partecipant 8 cannot insert {0: '08-15-1990', 1: '07:26', 2: 33, 3: 6}
# Skipped lines subject 8: 2
# Skipped lines subject 9: 0
# Skipped lines subject 10: 0
# Skipped lines subject 11: 0
# Cannot create EventLabel: instance with primary key Event[12,datetime.datetime(1990, 8, 30, 6, 29)], Label[33] already exists
# partecipant 12 cannot insert {0: '08-30-1990', 1: '06:29', 2: 33, 3: 8}
# Skipped lines subject 12: 1
# Skipped lines subject 13: 0
# Skipped lines subject 14: 0
# Skipped lines subject 15: 0
# Cannot create EventLabel: instance with primary key Event[16,datetime.datetime(1991, 7, 7, 21, 14)], Label[33] already exists
# partecipant 16 cannot insert {0: '07-07-1991', 1: '21:14', 2: 33, 3: 5}
# Cannot create EventLabel: instance with primary key Event[16,datetime.datetime(1991, 7, 7, 21, 14)], Label[34] already exists
# partecipant 16 cannot insert {0: '07-07-1991', 1: '21:14', 2: 34, 3: 4}
# Skipped lines subject 16: 2
# Cannot create EventLabel: instance with primary key Event[17,datetime.datetime(1990, 7, 16, 22, 19)], Label[33] already exists
# partecipant 17 cannot insert {0: '07-16-1990', 1: '22:19', 2: 33, 3: 2}
# Skipped lines subject 17: 1
# Cannot create EventLabel: instance with primary key Event[18,datetime.datetime(1990, 9, 14, 21, 36)], Label[34] already exists
# partecipant 18 cannot insert {0: '09-14-1990', 1: '21:36', 2: 34, 3: 1}
# Skipped lines subject 18: 1
# Cannot create EventLabel: instance with primary key Event[19,datetime.datetime(1990, 9, 14, 21, 36)], Label[34] already exists
# partecipant 19 cannot insert {0: '09-14-1990', 1: '21:36', 2: 34, 3: 1}
# Cannot create EventLabel: instance with primary key Event[19,datetime.datetime(1990, 9, 25, 7, 23)], Label[33] already exists
# partecipant 19 cannot insert {0: '09-25-1990', 1: '07:23', 2: 33, 3: 1}
# Cannot create EventLabel: instance with primary key Event[19,datetime.datetime(1990, 9, 27, 7, 32)], Label[34] already exists
# partecipant 19 cannot insert {0: '09-27-1990', 1: '07:32', 2: 34, 3: 1}
# Skipped lines subject 19: 3
# Label[4]
# partecipant 20 cannot insert {0: '05-26-1991', 1: '06:00', 2: 4, 3: 0}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '07:50', 2: 58, 3: 149}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '07:50', 2: 33, 3: 4}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '07:50', 2: 34, 3: 24}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '13:30', 2: 60, 3: 162}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '13:30', 2: 33, 3: 5}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '19:45', 2: 62, 3: 213}
# day is out of range for month
# partecipant 20 cannot insert {0: '06-31-1991', 1: '19:45', 2: 33, 3: 11}
# Skipped lines subject 20: 8
# Skipped lines subject 21: 0
# Label[36]
# partecipant 22 cannot insert {0: '03-14-1991', 1: '22:06', 2: 36, 3: 5}
# Skipped lines subject 22: 1
# Skipped lines subject 23: 0
# Skipped lines subject 24: 0
# Skipped lines subject 25: 0
# Skipped lines subject 26: 0
# Label[0]
# partecipant 27 cannot insert {0: '10-12-1989', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 27 cannot insert {0: nan, 1: '138', 2: 33, 3: '3A'}
# Label[0]
# partecipant 27 cannot insert {0: '10-12-1989', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 27 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 27 cannot insert {0: '10-12-1989', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 27 cannot insert {0: nan, 1: '016', 2: 33, 3: '22'}
# Skipped lines subject 27: 6
# Skipped lines subject 28: 0
# Label[0]
# partecipant 29 cannot insert {0: '05-25-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '201', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '05-25-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '004', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '05-25-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '07-02-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '202', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '07-02-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '07-02-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '07-14-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '195', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '07-14-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '07-14-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '07-17-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '168', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '07-17-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '07-17-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '07-28-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '226', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '07-28-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '07-28-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '08-03-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '162', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '08-03-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '08-03-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '08-27-1990', 1: '7:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '212', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '08-27-1990', 1: '7:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '08-27-1990', 1: '7:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '09-11-1990', 1: '6:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '169', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '09-11-1990', 1: '6:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '09-11-1990', 1: '6:30', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '018', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '11-08-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '217', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '11-08-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '11-08-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '020', 2: 33, 3: '22'}
# Label[0]
# partecipant 29 cannot insert {0: '11-29-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '209', 2: 33, 3: '3A'}
# Label[0]
# partecipant 29 cannot insert {0: '11-29-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '006', 2: 33, 3: '21'}
# Label[0]
# partecipant 29 cannot insert {0: '11-29-1990', 1: '7:00', 2: 0, 3: nan}
# unsupported operand type(s) for +: 'float' and 'str'
# partecipant 29 cannot insert {0: nan, 1: '020', 2: 33, 3: '22'}
# Skipped lines subject 29: 60
# Skipped lines subject 30: 0
# Skipped lines subject 31: 0
# Skipped lines subject 32: 0
# Skipped lines subject 33: 0
# Skipped lines subject 34: 0
# Skipped lines subject 35: 0
# Skipped lines subject 36: 0
# Skipped lines subject 37: 0
# Skipped lines subject 38: 0
# Skipped lines subject 39: 0
# Skipped lines subject 40: 0
# Skipped lines subject 41: 0
# Skipped lines subject 42: 0
# Cannot create EventLabel: instance with primary key Event[43,datetime.datetime(1990, 7, 26, 15, 8)], Label[65] already exists
# partecipant 43 cannot insert {0: '07-26-1990', 1: '15:08', 2: 65, 3: 0}
# Skipped lines subject 43: 1
# Skipped lines subject 44: 0
# Skipped lines subject 45: 0
# Skipped lines subject 46: 0
# Cannot create EventLabel: instance with primary key Event[47,datetime.datetime(1991, 5, 15, 6, 9)], Label[34] already exists
# partecipant 47 cannot insert {0: '05-15-1991', 1: '06:09', 2: 34, 3: 1}
# Skipped lines subject 47: 1
# Skipped lines subject 48: 0
# Skipped lines subject 49: 0
# Skipped lines subject 50: 0
# Cannot create EventLabel: instance with primary key Event[51,datetime.datetime(1991, 5, 5, 20, 35)], Label[34] already exists
# partecipant 51 cannot insert {0: '05-05-1991', 1: '20:35', 2: 34, 3: 5}
# Skipped lines subject 51: 1
# Cannot create EventLabel: instance with primary key Event[52,datetime.datetime(1991, 5, 5, 20, 35)], Label[34] already exists
# partecipant 52 cannot insert {0: '05-05-1991', 1: '20:35', 2: 34, 3: 5}
# Skipped lines subject 52: 1
# Skipped lines subject 53: 0
# Skipped lines subject 54: 0
# Skipped lines subject 55: 0
# Skipped lines subject 56: 0
# Skipped lines subject 57: 0
# Cannot create EventLabel: instance with primary key Event[58,datetime.datetime(1990, 8, 26, 20, 38)], Label[33] already exists
# partecipant 58 cannot insert {0: '08-26-1990', 1: '20:38', 2: 33, 3: 3}
# Skipped lines subject 58: 1
# Cannot create EventLabel: instance with primary key Event[59,datetime.datetime(1990, 9, 30, 7, 23)], Label[33] already exists
# partecipant 59 cannot insert {0: '09-30-1990', 1: '07:23', 2: 33, 3: 12}
# Skipped lines subject 59: 1
# Cannot create EventLabel: instance with primary key Event[60,datetime.datetime(1991, 5, 3, 17, 0)], Label[33] already exists
# partecipant 60 cannot insert {0: '05-03-1991', 1: '17:00', 2: 33, 3: 3}
# Skipped lines subject 60: 1
# Cannot create EventLabel: instance with primary key Event[61,datetime.datetime(1991, 5, 25, 19, 36)], Label[33] already exists
# partecipant 61 cannot insert {0: '05-25-1991', 1: '19:36', 2: 33, 3: 10}
# Skipped lines subject 61: 1
# Skipped lines subject 62: 0
# Cannot create EventLabel: instance with primary key Event[63,datetime.datetime(1991, 8, 17, 7, 28)], Label[33] already exists
# partecipant 63 cannot insert {0: '08-17-1991', 1: '07:28', 2: 33, 3: 7}
# Skipped lines subject 63: 1
# Skipped lines subject 64: 0
# Skipped lines subject 65: 0
# Skipped lines subject 66: 0
# time data '04-09-1991 56:35' does not match format '%m-%d-%Y %H:%M'
# partecipant 67 cannot insert {0: '04-09-1991', 1: '56:35', 2: 58, 3: 237}
# time data '04-09-1991 56:35' does not match format '%m-%d-%Y %H:%M'
# partecipant 67 cannot insert {0: '04-09-1991', 1: '56:35', 2: 33, 3: 16}
# time data '04-09-1991 56:35' does not match format '%m-%d-%Y %H:%M'
# partecipant 67 cannot insert {0: '04-09-1991', 1: '56:35', 2: 34, 3: 40}
# time data '04-21-1991 188:00' does not match format '%m-%d-%Y %H:%M'
# partecipant 67 cannot insert {0: '04-21-1991', 1: '188:00', 2: 62, 3: 128}
# time data '04-21-1991 188:00' does not match format '%m-%d-%Y %H:%M'
# partecipant 67 cannot insert {0: '04-21-1991', 1: '188:00', 2: 33, 3: 14}
# Skipped lines subject 67: 5
# Skipped lines subject 68: 0
# Skipped lines subject 69: 0
# Skipped lines subject 70: 0

# %%
df = Event.full_dataset()

print(Event.count_seq([33, 34], 1, 4, 1))
# Out:
# 131

# %%
def support(T, X):
    if len(T) == 0 or len(X) == 0:
        return 0

    count = 0
    for t in T:
        if has_subseq(t, X):
            count += 1
    return count / len(T)

# %%
def rule_support(T, X, Y):
    print(f"support({X} -> {Y}) = {support(T, X + Y)}")
    return support(T, X + Y)

# %%
def confidence(T, X, Y):
    """
    Compute the confidence of the rule X -> Y in the transactions T.
    """
    a = support(T, X + Y)
    b = support(T, X)
    if a == 0 or b == 0:
        return 0
    return a / b

# %%
from math import factorial
import itertools


def rule_shapley(T, q, X, Y):
    """
    Compute the Shapley value of every element in X.
    """

    def shapley(T, q, X, Y, x):
        """
        Compute the Shapley value of x in X.
        """
        print(f"Computing Shapley value of {x}")
        n = len(X)
        sum = 0
        for p in itertools.permutations(X):
            S = list(p)[: p.index(x)]
            print(
                f"S : {list(S)}, marginal cuntribute : {q(T, list(S) + [x], Y) - q(T, list(S), Y)}"
            )
            sum += q(T, list(S) + [x], Y) - q(T, list(S), Y)

        return sum / factorial(n)

    def ret_func(x):
        return shapley(T, q, X, Y, x)

    return ret_func

# %%
ds = Event.event_slices(1, 4, 1)
print(ds)

q = confidence
X = [33, 34, 58]
Y = [62]
print(q(ds, X, Y))
rs = rule_shapley(ds, q, X, Y)

svs = [rs(x) for x in X]
print("Shapley values: ")
for i in range(len(X)):
    print(f"{X[i]}: {svs[i]}")
print(f"Sum of Shapley values: {sum(svs)}")
# Out:
